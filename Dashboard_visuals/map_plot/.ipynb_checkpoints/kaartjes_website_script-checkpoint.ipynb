# %%
import pandas as pd
from bokeh.tile_providers import get_provider, Vendors
from bokeh.plotting import figure, show
from pyproj import Proj, transform
from bokeh.models.markers import Circle
from bokeh.models import ColumnDataSource
from bokeh.models.glyphs import Text
from bokeh.io import export_png, output_notebook
from bokeh.models import Legend
from bokeh.models import Arrow, OpenHead, NormalHead, VeeHead, Label
import os

# %%
data_path = '/home/thoverga/Documents/VLINDER/vlinder_dashboard/vlinder/api/data.csv'

# %%
savedirectroy = "/home/thoverga/Documents/VLINDER/vlinder_kaarten/output/"

# %%
data = pd.read_csv(data_path)

# %%
data.head()
# Out:
#                          ID    VLINDER        lat       lon  water20  \
# 0  jvy7zdAPZ5ymI2hydh6tvnmm  vlinder01  50.980438  3.815763      0.0
# 1  zZ6ZeSg11dJ5zp5GrNwNck9A  vlinder02  51.022379  3.709695      0.0
# 2  VDwYVFKNaGF0YpQtM4xe3Ic5  vlinder03  51.324583  4.952109      0.0
# 3  vqYF3lib7K3re0Zc38ZCzlom  vlinder04  51.335635  4.934690      0.0
# 4  2kfOFUtZ5wZEEpM6xbL42aFM  vlinder05  51.052700  3.675100      1.0
#
#    verhard20   groen20   water50  verhard50   groen50  \
# 0   0.085851  0.914149  0.000000   0.055994  0.944006
# 1   0.000000  1.000000  0.000000   0.314562  0.685438
# 2   0.386635  0.613365  0.000000   0.691240  0.308760
# 3   0.000000  1.000000  0.000000   0.000000  1.000000
# 4   0.000000  0.000000  0.773296   0.087184  0.139520
#
#                   ...                   water250  verhard250  groen250  \
# 0                 ...                   0.000000    0.068036  0.931964
# 1                 ...                   0.000000    0.463547  0.536453
# 2                 ...                   0.000000    0.820621  0.179379
# 3                 ...                   0.035652    0.122955  0.841393
# 4                 ...                   0.227974    0.257391  0.514635
#
#    water500  verhard500  groen500      stad        benaming        school  \
# 0  0.000924    0.102948  0.896127     Melle      Proefhoeve         UGent
# 1  0.048093    0.426543  0.525364      Gent          Sterre         UGent
# 2  0.006392    0.755716  0.237892  Turnhout         Centrum   Heilig Graf
# 3  0.043961    0.201841  0.754198  Turnhout  Stadsboerderij   Heilig Graf
# 4  0.124820    0.157484  0.717696      Gent  Watersportbaan  Sint-Barbara
#
#                                sponsor
# 0                    Universiteit Gent
# 1                    Universiteit Gent
# 2                        Stad Turnhout
# 3                        Stad Turnhout
# 4  UGent Volkssterrenwacht Armand Pien
#
# [5 rows x 23 columns]

# %%
vlinderlijst = list(data['VLINDER'].unique())

landcovers = ['groen', 'verhard', 'water'] #volgorde van belang voor de stack 
#landcover_colors = ['green', 'red', 'blue'] #volgorde corresponderend met landcovers
landcover_colors = ["#6ebd02","#8c8c8c", "#00afff"] #groen - grijs - blauw
#landcover_colors = ["#6ebd02","#d12f06", "#00afff"] #groen - rood - blauw
buffers = ['20', '50', '100', '250', '500']

# %%
def make_stacked_hist(station, data, landcovers = landcovers, landcover_colors = landcover_colors, buffers = buffers, save_directory = savedirectroy):
    subdf = data[data['VLINDER'] == station] #subsetting data
    
    #refactor data in dictionary

    histdict = {x:[] for x in landcovers}
    histdict['buffers'] = buffers

    for buf in buffers:
        for landcovertype in landcovers:
            columnname = landcovertype + buf
            histdict[landcovertype].append(subdf[columnname].iloc[0])
            
    #create figure
    p = figure(x_range=histdict['buffers'], plot_height=250,
           toolbar_location=None, tools="")

    p.vbar_stack(landcovers, x='buffers', width=0.9, color=landcover_colors, fill_alpha = 0.7, source=histdict,
                 legend_label=landcovers)

    p.xaxis.axis_label = 'Buffer straal (m)'
    p.yaxis.axis_label = 'Fractie'


    p.axis.axis_label_text_font_style = 'bold'
    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None

    p.xaxis.major_label_text_font_style = 'bold'
    p.yaxis.major_label_text_font_style = 'bold'

    p.y_range.start = 0
    p.x_range.range_padding = 0.1
    p.xgrid.grid_line_color = None
    p.axis.minor_tick_line_color = None
    p.outline_line_color = None
    p.legend.location = "bottom_center"
    p.legend.orientation = "horizontal"
    
    p.background_fill_alpha= 0.0
    p.border_fill_alpha = 0.0
    p.background_fill_color = None
    p.border_fill_color = None
    
    
    

    p.xgrid.grid_line_color = None
    p.axis.minor_tick_line_color = None
    p.outline_line_color = None
    p.legend.location = "bottom_center"
    p.legend.orientation = "horizontal"


    p.xaxis.axis_line_width = 3 
    p.yaxis.axis_line_width = 3 
    p.xaxis.axis_label_text_font_size = '17pt'
    p.yaxis.axis_label_text_font_size = '15pt'
    p.xaxis.axis_label_text_font_style = 'bold'
    p.yaxis.axis_label_text_font_style = 'bold'

    p.yaxis.major_label_text_font_style = "bold"
    p.yaxis.major_label_text_font_size = '15pt'
    p.xaxis.major_label_text_font_style = "bold"
    p.xaxis.major_label_text_font_size = '15pt'

    p.legend.label_text_font_size = "15pt"
    p.legend.border_line_width = 3
    p.legend.border_line_color = "navy"
    p.legend.border_line_alpha = 0.5
    #p.legend.background_fill_color = "grey"
    p.legend.background_fill_alpha = 0.8

    p.background_fill_color = "#000000"
    p.border_fill_color = "#000000"
    p.background_fill_alpha= 0.0
    p.border_fill_alpha = 0.0
    
    #save figure
    figure_location = save_directory + "/stacked_" + station + ".png"
    
    export_png(p, filename= figure_location)
    print("Stacked histograme saved here: " + figure_location)
    return figure_location

# %%
def makefigure(station,optie,savedirectory,data, with_stacked_barchart = False, landcovers = landcovers, landcover_colors = landcover_colors, buffers = buffers, save_directory = savedirectroy):
    print(station)
    
    subdata = data[data["VLINDER"] == station]
    
    

    def projectie(subdata):
        # The coordinates have to be transformed from latlon to mercator
        inProj = Proj(init='epsg:4326') #lat lon coordinate system
        outProj = Proj(init='epsg:3857') # mercator coordinate system
        lat = list(subdata["lon"])[0]
        lon = list(subdata["lat"])[0]
        
        proj = transform(inProj, outProj, lat, lon)
        
        y_mercator = proj[0]
        x_mercator = proj[1]
        return x_mercator, y_mercator
    x,y = projectie(subdata)
    

    


    school = list(subdata['school'])[0]
    naam = list(subdata['VLINDER'])[0]
    stad = list(subdata['stad'])[0]
    titel = naam +' (' + stad + ') - ' + school
    
    print(titel)


    #output_file("tile.html")
    #kaart = get_provider(Vendors.STAMEN_TONER) #kaart1
    #kaart = get_provider(Vendors.CARTODBPOSITRON) #kaart2
    #kaart = get_provider(Vendors.CARTODBPOSITRON_RETINA) #kaart3
    kaart = get_provider(Vendors.STAMEN_TERRAIN) #kaart4
    #kaart = get_provider(Vendors.STAMEN_TERRAIN_RETINA) #kaart5
    #kaart = get_provider(Vendors.STAMEN_TONER_BACKGROUND) #kaart6

    if (optie):

        xrange = 7000.
        yrange = 3500.
        xmin = x -(xrange * 0.4)
        xmax = x + (xrange * 0.6)
        leftfraction = 0.01
        ymin = y - (yrange * leftfraction)
        ymax = y + (yrange * (1-leftfraction))
        

        figuur = figure(x_range=(ymin, ymax), y_range=(xmin, xmax), x_axis_type="mercator", y_axis_type="mercator", plot_width=600, plot_height=300)
        figuur.add_tile(kaart)
        figuur.title.text = titel
        figuur.toolbar.logo = None
        figuur.toolbar_location = None
        figuur.title.text_font_size = '16pt'
        figuur.axis.visible = False
    
        #show(figuur)

   
        source = ColumnDataSource(subdata)
    

        dots = Circle(x=y, y=x, size=12, fill_color="red", fill_alpha=0.8, line_color=None)

        lengtefactor = 1./8.
        lengtefactor_arrow = 8./5.

        glyph20 = Circle(x=y, y=x, size=20*lengtefactor, line_color="#3288bd", line_width=3, fill_alpha = 0.0)
        glyph50 = Circle(x=y, y=x, size=50*lengtefactor, line_color="#3288bd", line_width=3, fill_alpha = 0.0)
        glyph100 = Circle(x=y, y=x, size=100*lengtefactor, line_color="#3288bd", line_width=3, fill_alpha = 0.0)
        glyph250 = Circle(x=y, y=x, size=250*lengtefactor, line_color="#3288bd", line_width=3, fill_alpha = 0.0)
        glyph500 = Circle(x=y, y=x, size=500*lengtefactor, line_color="#3288bd", line_width=3, fill_alpha = 0.0)


        #figuur.add_layout(Arrow(end=NormalHead(fill_color="#3288bd", size=10), x_start=y, y_start=x, x_end=y+500*lengtefactor_arrow, y_end=x))

        mytext = Label(x=y + 1300, y=x-400, text='500m', text_font_size = "10pt", text_color = "#3288bd", angle = 1.57 )
        #figuur.add_layout(mytext)


        #figuur.add_glyph(source, glyph20)
        #figuur.add_glyph(source, glyph50)
        #figuur.add_glyph(source, glyph100)
        #figuur.add_glyph(source, glyph250)
        #figuur.add_glyph(source, glyph500)

        figuur.add_glyph(source, dots)

        #print(savedirectory+station+"_plot_no_background.png")
        #figuur.image_url(url=[savedirectory + station + "_plot_no_background.png"], x=y+(xrange * 0.1)+1200, y=x+(yrange*1.15), w=1.1*xrange, h=0.95*yrange)
        #figuur.image_url(url=['/home/thomas/Documents/VLINDER/Sever code/plot.png'], x=y+(xrange * 0.1), y=x+(yrange*1.15), w=1.1*xrange, h=0.95*yrange)
    
    
    
        figuur.image_url(url=['/home/thoverga/Documents/VLINDER/vlinder_kaarten/north.png'], x=y+(xrange * 1.04)+1200, y=x-(yrange*0.3), w=0.2*xrange, h=0.2*xrange)
        figuur.image_url(url=['/home/thoverga/Documents/VLINDER/vlinder_kaarten/test2.png'], x=y+(xrange * 0.47)+1200, y=x-(yrange*0.48), w=0.55*xrange, h=0.1*xrange)
    else :

        xrange = 7000.
        yrange = 3500.
        xmin = x -(xrange * 0.4)
        xmax = x + (xrange * 0.6)
        leftfraction = 0.9
        ymin = y - (yrange * leftfraction)
        ymax = y + (yrange * (1-leftfraction))
        
        

        figuur = figure(x_range=(ymin, ymax), y_range=(xmin, xmax), x_axis_type="mercator", y_axis_type="mercator", plot_width=600, plot_height=300)
        figuur.add_tile(kaart)
        figuur.title.text = titel
        figuur.toolbar.logo = None
        figuur.toolbar_location = None
        figuur.title.text_font_size = '16pt'
        figuur.axis.visible = False
    
        #show(figuur)

   
        source = ColumnDataSource(subdata)
    

        dots = Circle(x=y, y=x, size=12, fill_color="red", fill_alpha=0.8, line_color=None)

        lengtefactor = 1./8.
        lengtefactor_arrow = 8./5.

        glyph20 = Circle(x=y, y=x, size=20*lengtefactor, line_color="#3288bd", line_width=3, fill_alpha = 0.0)
        glyph50 = Circle(x=y, y=x, size=50*lengtefactor, line_color="#3288bd", line_width=3, fill_alpha = 0.0)
        glyph100 = Circle(x=y, y=x, size=100*lengtefactor, line_color="#3288bd", line_width=3, fill_alpha = 0.0)
        glyph250 = Circle(x=y, y=x, size=250*lengtefactor, line_color="#3288bd", line_width=3, fill_alpha = 0.0)
        glyph500 = Circle(x=y, y=x, size=500*lengtefactor, line_color="#3288bd", line_width=3, fill_alpha = 0.0)


        #figuur.add_layout(Arrow(end=NormalHead(fill_color="#3288bd", size=10), x_start=y, y_start=x, x_end=y+500*lengtefactor_arrow, y_end=x))

        mytext = Label(x=y + 1300, y=x-400, text='500m', text_font_size = "10pt", text_color = "#3288bd", angle = 1.57 )
        figuur.add_layout(mytext)


        figuur.add_glyph(source, glyph20)
        figuur.add_glyph(source, glyph50)
        figuur.add_glyph(source, glyph100)
        figuur.add_glyph(source, glyph250)
        figuur.add_glyph(source, glyph500)

        figuur.add_glyph(source, dots)

    
        figuur.image_url(url=[savedirectory + station + "_plot.png"], x=y-(xrange * 1.5)+1400, y=x+(yrange*1.15), w=1.1*xrange, h=0.95*yrange)
        #figuur.image_url(url=['/home/thomas/Documents/VLINDER/Sever code/plot.png'], x=y+(xrange * 0.1), y=x+(yrange*1.15), w=1.1*xrange, h=0.95*yrange)
    
    
    
        figuur.image_url(url=['/home/thoverga/Documents/VLINDER/vlinder_kaarten/north.png'], x=y+(xrange * 0.6)+1350, y=x-(yrange*0.3), w=0.2*xrange, h=0.2*xrange)
        figuur.image_url(url=['/home/thoverga/Documents/VLINDER/vlinder_kaarten/test2.png'], x=y+(xrange * 0.1)+1000, y=x-(yrange*0.48), w=0.55*xrange, h=0.1*xrange)
    
    
    if with_stacked_barchart:
        bar_im_location = make_stacked_hist(station, data)
        
        #figuur.image_url(url=[bar_im_location],anchor = 'top_right', x = ymax, y = xmax, w = 9000, h = 3000)
        figuur.image_url(url=[bar_im_location],anchor = 'top_right', x = ymax + 6400, y = xmax, w = 8000, h = 3000)
    
    
    export_png(figuur, filename=save_directory+naam+".png")
    
    return figuur

# %%
#figuur = makefigure('vlinder28', True, savedirectroy,data = data, with_stacked_barchart = True)

# %%
#show(figuur)

# %%
for stationname in vlinderlijst:
    print('creating figure for ', stationname)
    figuur = makefigure(stationname, True, savedirectroy,data = data, with_stacked_barchart = True)
    #show(figuur)
# Out:
# creating figure for  vlinder01
# vlinder01
# vlinder01 (Melle) - UGent
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder01.png
# creating figure for  vlinder02
# vlinder02
# vlinder02 (Gent) - UGent
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder02.png
# creating figure for  vlinder03
# vlinder03
# vlinder03 (Turnhout) - Heilig Graf
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder03.png
# creating figure for  vlinder04
# vlinder04
# vlinder04 (Turnhout) - Heilig Graf
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder04.png
# creating figure for  vlinder05
# vlinder05
# vlinder05 (Gent) - Sint-Barbara
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder05.png
# creating figure for  vlinder06
# vlinder06
# vlinder06 (Bonheiden) - BimSem
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder06.png
# creating figure for  vlinder07
# vlinder07
# vlinder07 (Mechelen) - PTS
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder07.png
# creating figure for  vlinder08
# vlinder08
# vlinder08 (Mechelen) - TSM
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder08.png
# creating figure for  vlinder09
# vlinder09
# vlinder09 (Aalst) - SMI
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder09.png
# creating figure for  vlinder10
# vlinder10
# vlinder10 (Aalst) - SMI
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder10.png
# creating figure for  vlinder11
# vlinder11
# vlinder11 (Antwerpen) - Sint-Annacollege
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder11.png
# creating figure for  vlinder12
# vlinder12
# vlinder12 (Antwerpen) - ZOO Antwerpen
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder12.png
# creating figure for  vlinder13
# vlinder13
# vlinder13 (Antwerpen) - ITG
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder13.png
# creating figure for  vlinder14
# vlinder14
# vlinder14 (Antwerpen) - UGent
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder14.png
# creating figure for  vlinder15
# vlinder15
# vlinder15 (Asse) - Sint-Martinus
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder15.png
# creating figure for  vlinder16
# vlinder16
# vlinder16 (Beveren) - Sint-Maarten
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder16.png
# creating figure for  vlinder17
# vlinder17
# vlinder17 (Oudsbergen) - Sint-Augustinusinstituut Bree
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder17.png
# creating figure for  vlinder18
# vlinder18
# vlinder18 (Bree) - TISM Bree
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder18.png
# creating figure for  vlinder19
# vlinder19
# vlinder19 (Brussel) - UGent
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder19.png
# creating figure for  vlinder20
# vlinder20
# vlinder20 (Brussel) - Vivaqua
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder20.png
# creating figure for  vlinder21
# vlinder21
# vlinder21 (De Haan) - Zeelyceum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder21.png
# creating figure for  vlinder22
# vlinder22
# vlinder22 (Diksmuide) - ‘t Saam
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder22.png
# creating figure for  vlinder23
# vlinder23
# vlinder23 (Sint-Laureins) - PTI Eeklo
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder23.png
# creating figure for  vlinder24
# vlinder24
# vlinder24 (Eeklo) - OLV ten Doorn
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder24.png
# creating figure for  vlinder25
# vlinder25
# vlinder25 (Evergem) - Einstein Atheneum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder25.png
# creating figure for  vlinder26
# vlinder26
# vlinder26 (Geel) - Sint Dimpna
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder26.png
# creating figure for  vlinder27
# vlinder27
# vlinder27 (Gent) - Sec. Kunstinstituut
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder27.png
# creating figure for  vlinder28
# vlinder28
# vlinder28 (Gent) - GO! Ath.
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder28.png
# creating figure for  vlinder29
# vlinder29
# vlinder29 (Gent) - Einstein Atheneum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder29.png
# creating figure for  vlinder30
# vlinder30
# vlinder30 (Antwerpen) - KMI
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder30.png
# creating figure for  vlinder31
# vlinder31
# vlinder31 (Heist-op-den-Berg) - GO! Atheneum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder31.png
# creating figure for  vlinder32
# vlinder32
# vlinder32 (Heist-op-den-Berg) - Sint Lambertus
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder32.png
# creating figure for  vlinder33
# vlinder33
# vlinder33 (Herentals) - GO! SO De Vesten
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder33.png
# creating figure for  vlinder34
# vlinder34
# vlinder34 (Ieper) - Samenwerking Ieper
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder34.png
# creating figure for  vlinder35
# vlinder35
# vlinder35 (Keerbergen) - GO! Atheneum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder35.png
# creating figure for  vlinder36
# vlinder36
# vlinder36 (Koekelberg) - Koninklijk Ath.
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder36.png
# creating figure for  vlinder37
# vlinder37
# vlinder37 (Kontich) - VTI
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder37.png
# creating figure for  vlinder38
# vlinder38
# vlinder38 (Lier) - Atheneum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder38.png
# creating figure for  vlinder39
# vlinder39
# vlinder39 (Lommel) - WICO
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder39.png
# creating figure for  vlinder40
# vlinder40
# vlinder40 (Londerzeel) - GTIL
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder40.png
# creating figure for  vlinder41
# vlinder41
# vlinder41 (Maaseik) - Mosa-RT
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder41.png
# creating figure for  vlinder42
# vlinder42
# vlinder42 (Maldegem) - Maricolen
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder42.png
# creating figure for  vlinder43
# vlinder43
# vlinder43 (Menen) - Sint-Aloysiuscollege
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder43.png
# creating figure for  vlinder44
# vlinder44
# vlinder44 (Nieuwpoort) - Sint-Bernardus
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder44.png
# creating figure for  vlinder45
# vlinder45
# vlinder45 (Oudenaarde) - Bernardustechnicum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder45.png
# creating figure for  vlinder46
# vlinder46
# vlinder46 (Oudenaarde) - Bernardustechnicum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder46.png
# creating figure for  vlinder47
# vlinder47
# vlinder47 (Pelt) - VOX Atheneum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder47.png
# creating figure for  vlinder48
# vlinder48
# vlinder48 (Sint-Niklaas) - VTS
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder48.png
# creating figure for  vlinder49
# vlinder49
# vlinder49 (Sint-Niklaas) - Berkenboom
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder49.png
# creating figure for  vlinder50
# vlinder50
# vlinder50 (Sint-Truiden) - Hasp-O-Centrum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder50.png
# creating figure for  vlinder51
# vlinder51
# vlinder51 (Gingelom) - Het Kompas
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder51.png
# creating figure for  vlinder52
# vlinder52
# vlinder52 (Tielt) - VTI
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder52.png
# creating figure for  vlinder53
# vlinder53
# vlinder53 (Tielt) - VTI
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder53.png
# creating figure for  vlinder54
# vlinder54
# vlinder54 (Tienen) - VIA
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder54.png
# creating figure for  vlinder55
# vlinder55
# vlinder55 (De Panne) - GO! Ath. Veurne
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder55.png
# creating figure for  vlinder56
# vlinder56
# vlinder56 (Vorselaar) - Thomas More
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder56.png
# creating figure for  vlinder57
# vlinder57
# vlinder57 (Zelzate) - GO! Atheneum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder57.png
# creating figure for  vlinder58
# vlinder58
# vlinder58 (Zelzate) - Sint-Laurens
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder58.png
# creating figure for  vlinder59
# vlinder59
# vlinder59 (Melle) - UGent
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder59.png
# creating figure for  vlinder60
# vlinder60
# vlinder60 (Ieper) - Consortium Ieper
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder60.png
# creating figure for  vlinder61
# vlinder61
# vlinder61 (Maldegem) - GO! Atheneum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder61.png
# creating figure for  vlinder62
# vlinder62
# vlinder62 (Geraardsbergen) - Koninklijk Atheneum
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder62.png
# creating figure for  vlinder63
# vlinder63
# vlinder63 (Mechelen) - BA Nekkerspoel
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder63.png
# creating figure for  vlinder64
# vlinder64
# vlinder64 (Mechelen) - BA Pitzemburg
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder64.png
# creating figure for  vlinder65
# vlinder65
# vlinder65 (Herzele) - Atheneum Herzele
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder65.png
# creating figure for  vlinder66
# vlinder66
# vlinder66 (Ninove) - Hartencollege
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder66.png
# creating figure for  vlinder67
# vlinder67
# vlinder67 (Zottegem) - KAZ Zottegem
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder67.png
# creating figure for  vlinder68
# vlinder68
# vlinder68 (Lier) - VTI Lier
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder68.png
# creating figure for  vlinder69
# vlinder69
# vlinder69 (Lommel) - X Plus
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder69.png
# creating figure for  vlinder70
# vlinder70
# vlinder70 (Langemark-Poelkapelle) - Koninklijke Militaire School (KMS)
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder70.png
# creating figure for  vlinder71
# vlinder71
# vlinder71 (Gent) - UGent
# Stacked histograme saved here: /home/thoverga/Documents/VLINDER/vlinder_kaarten/output//stacked_vlinder71.png
