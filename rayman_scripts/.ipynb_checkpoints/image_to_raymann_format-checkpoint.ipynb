# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import imutils
import pandas as pd

# %%
# store images in a list
image_path = 'VLINDER_foto'
images = os.listdir(image_path)
image_index= 0
img = cv2.imread(image_path+'/'+images[image_index], 0)


#debug
image_path = "/home/thoverga/Documents/VLINDER_github/VLINDER/rayman_scripts/VLINDER_foto/fisheye_32.jpg"
img=cv2.imread(image_path)

# %%
#plot image
print(img.dtype)
plt.imshow(img)
plt.show()
# Out:
# uint8

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edged = cv2.Canny(gray, 80, 200)
plt.imshow(edged)
plt.show()

# %%
#1. Remove rectangular borders 
img[15,18]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
#2. locate the dark pixels near the boarders

test_img = img
#plt.imshow(test_img)
#plt.show()




def get_distance(index, figshape):
    return min(min(pd.Series(index)), min(pd.Series(figshape) - pd.Series(index)))
    

#matrix to index - value pair
figsize = test_img.shape[0:2]
distance_list = []
value_list = []
value_list_R = []
value_list_G = []
value_list_B = []
index_list = []
blue_image = test_img[:,:,0]
for index, value in np.ndenumerate(blue_image):
    distance_list.append(get_distance(index[0:2], figsize))
    values = test_img[index]
    value_list.append(values)
    index_list.append(index)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_44142/3918328401.py in <module>
#      22 blue_image = test_img[:,:,0]
#      23 for index, value in np.ndenumerate(blue_image):
# ---> 24     distance_list.append(get_distance(index[0:2], figsize))
#      25     values = test_img[index]
#      26     value_list.append(values)
#
# /tmp/ipykernel_44142/3918328401.py in get_distance(index, figshape)
#       9
#      10 def get_distance(index, figshape):
# ---> 11     return min(min(pd.Series(index)), min(pd.Series(figshape) - pd.Series(index)))
#      12
#      13
#
# ~/anaconda3/envs/MLenv/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ...

# %%
df = pd.DataFrame()

df["distance"]=distance_list
df["index"] = index_list
df["value"] = value_list

df['R'] = [x[0] for x in df['value']]
df['G'] = [x[1] for x in df['value']]
df['B'] = [x[2] for x in df['value']]



df.plot(x='distance', y='R', kind='scatter')
# Out:
# <AxesSubplot:xlabel='distance', ylabel='R'>

# %%
img.item(0,0,0)
# Out:
# 0

# %%
# find contours in the image and initialize the mask that will be
# used to remove the bad contours
cnts = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
mask = np.ones(img.shape[:2], dtype="uint8") * 255

# %%
contour = cnts[1]
#print(contour)

test = cv2.drawContours(mask, [contour], -1,0,-1)

plt.imshow(test)
plt.show(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_44142/3414989058.py in <module>
#       5
#       6 plt.imshow(test)
# ----> 7 plt.show(test)
#
# ~/anaconda3/envs/MLenv/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# ~/anaconda3/envs/MLenv/lib/python3.7/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# cv2.cvtColor is applied over the
# image input with applied parameters
# to convert the image in grayscale
img_g = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(img_g.dtype)
Res = img.shape[0:2]
print("Resolution: ",Res)
plt.imshow(img_g)
plt.show()
# Out:
# uint8

# %%
#mask the boarder
#(_, mask) = cv2.threshold(img, 1.0, 240.0, cv2.THRESH_BINARY)

# Otsu's thresholding
ret2,th2 = cv2.threshold(img_g,120,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
th2 = cv2.adaptiveThreshold(img_g,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
print(th2)

plt.imshow(th2)
plt.show()
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
# findContours destroys input
temp = mask.copy()
temp = cv2.cvtColor(temp, cv2.COLOR_BGR2GRAY) #convert to grayscale
temp
contours = cv2.findContours(temp, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# sort contours by largest first (if there are more than one)
contours = sorted(contours, key=lambda contour:len(contour), reverse=True)
roi = cv2.boundingRect(contours[0])
roi
# Out:
# (0, 0, 1536, 2048)

# %%
# use the roi to select into the original 'stitched' image
end_img = img[roi[1]:roi[3], roi[0]:roi[2]]

plt.imshow(end_img)
plt.show()
